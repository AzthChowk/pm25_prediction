# %%
import pandas as pd

# %%
# # load the data
# # bhaisepati_2022_df = pd.read_csv('y_2023_Bhaisipati PM2.5 hourlyaverage.csv')
# bhaisepati_2023_df = pd.read_csv('./datasets/Pm25 record data/y_2023_Bhaisipati PM2.5 hourlyaverage.csv')
# bhaisepati_2024_df = pd.read_csv('./datasets/Pm25 record data/y_2024_Bhaisipati PM2.5 hourlyaverage.csv')
# # 2023 data
# print("=== 2023 ===")
# print(bhaisepati_2023_df.head())
# print("\n=== Basic information Bhaisepati year 2024 ===")
# print(bhaisepati_2023_df.info())
# print("\n=== Null Values ===")
# print(bhaisepati_2023_df.isnull().sum())
# # 2024 data
# print("\n=== 2024 ===")
# print(bhaisepati_2024_df.head())
# print("\n=== Basic information Bhaisepati year 2024 ===")
# print(bhaisepati_2024_df.info())
# print("\n=== Null Values ===")
# print(bhaisepati_2024_df.isnull().sum())

# %%
locations = ['bhaisipati','bhaktapur','khumaltar','kirtipur','pulchowk','ratnapark','shankhapark']
years = [2022, 2023, 2024]

# %%
# for i in years:
#     for j in locations:
#         i_df_j = pd.read_csv(f"./datasets/Pm25 record data/y_{i}_{j} PM2.5 hourlyaverage.csv")
#         print("============================== \n")
#         print(f"{i}_df_{j}".upper())
#         print(i_df_j.info())
#         print("\n=== Missing values info ===")
#         print(i_df_j.isnull().sum())

try:
    for i in years:
        for j in locations:
            i_df_j = pd.read_csv(f"./datasets/Pm25 record data/y_{i}_{j} PM2.5 hourlyaverage.csv")
            print("============================== \n")
            print(f"{i}_df_{j}")
            print(i_df_j.info())
            print("\n=== Missing values info ===")
            print(i_df_j.isnull().sum())
except:
    print("Something went wrong")
# Out:
# ...
#
# 2024_df_kirtipur
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8784 non-null   int64
#  1   date        8784 non-null   object
#  2   PM2.5       3346 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 206.0+ KB
# None
#
# === Missing values info ===
# Unnamed: 0       0
# date             0
# PM2.5         5438
# dtype: int64
# ...
#
# 2024_df_ratnapark
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8784 non-null   int64
#  1   date        8784 non-null   object
#  2   PM2.5       6651 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 206.0+ KB
# None
#
# === Missing values info ===
# Unnamed: 0       0
# ...

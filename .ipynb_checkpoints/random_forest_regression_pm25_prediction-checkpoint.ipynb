# %% [markdown]
# ## Pm2.5 Prediction using RandomForest Regression

# %%
import pandas as pd 
import numpy as np 
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score 
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('./datasets/ratnapark_pm25_after_imputation.csv')

# %%
df = df[['PM2.5',	'MO',	'DY',	'HR',	'PS',	'WS2M',	'WD2M',	'WS10M',	'WD10M',	'PRECTOTCORR',	'RH2M',	'QV2M',	'T2M']]
df
# Out:
#             PM2.5  MO  DY  HR     PS  WS2M   WD2M  WS10M  WD10M  PRECTOTCORR  \
# 0       75.780952   1   1   0  88.03  0.47  317.6   0.77  319.2          0.0
# 1       56.584127   1   1   1  88.00  0.40  310.0   0.64  313.7          0.0
# 2       49.538710   1   1   2  87.96  0.26  319.6   0.46  323.9          0.0
# 3       47.398438   1   1   3  87.93  0.28  300.3   0.46  306.1          0.0
# 4       42.821875   1   1   4  87.91  0.29  329.0   0.51  330.4          0.0
# ...           ...  ..  ..  ..    ...   ...    ...    ...    ...          ...
# 26299   74.526667  12  31  19  87.83  0.62  256.0   1.44  253.1          0.0
# 26300   84.556666  12  31  20  87.85  0.44  262.2   0.92  263.7          0.0
# 26301  105.226666  12  31  21  87.85  0.45  266.2   1.00  261.4          0.0
# 26302  107.503333  12  31  22  87.85  0.58  279.0   1.19  274.8          0.0
# 26303   91.450000  12  31  23  87.80  0.59  285.7   1.11  284.0          0.0
#
#         RH2M  QV2M    T2M
# 0      83.08  6.70   8.85
# 1      80.28  6.48   8.86
# 2      78.29  6.27   8.74
# 3      77.32  6.02   8.32
# 4      75.66  5.80   8.09
# ...      ...   ...    ...
# 26299  92.40  8.28  10.37
# 26300  91.04  7.94   9.97
# 26301  91.15  7.68   9.46
# 26302  89.81  7.39   9.11
# 26303  87.91  7.11   8.85
#
# [26304 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26304 entries, 0 to 26303
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PM2.5        26304 non-null  float64
#  1   MO           26304 non-null  int64
#  2   DY           26304 non-null  int64
#  3   HR           26304 non-null  int64
#  4   PS           26304 non-null  float64
#  5   WS2M         26304 non-null  float64
#  6   WD2M         26304 non-null  float64
#  7   WS10M        26304 non-null  float64
#  8   WD10M        26304 non-null  float64
#  9   PRECTOTCORR  26304 non-null  float64
#  10  RH2M         26304 non-null  float64
#  11  QV2M         26304 non-null  float64
#  12  T2M          26304 non-null  float64
# dtypes: float64(10), int64(3)
# memory usage: 2.6 MB

# %%
df_corr_spearman = df.corr(method='spearman', min_periods=1, numeric_only=False,)
df_corr_spearman
# Out:
#                 PM2.5        MO        DY        HR        PS      WS2M  \
# PM2.5        1.000000 -0.196439 -0.027757 -0.021775  0.480250 -0.109241
# MO          -0.196439  1.000000  0.010024  0.000000  0.054900 -0.168705
# DY          -0.027757  0.010024  1.000000  0.000000 -0.001832 -0.002653
# HR          -0.021775  0.000000  0.000000  1.000000  0.001271  0.108215
# PS           0.480250  0.054900 -0.001832  0.001271  1.000000 -0.140867
# WS2M        -0.109241 -0.168705 -0.002653  0.108215 -0.140867  1.000000
# WD2M         0.074952 -0.065090 -0.026204  0.232124  0.087326  0.101109
# WS10M       -0.136749 -0.161596 -0.003914  0.138527 -0.172759  0.987510
# PM2.5       -0.171238 -0.035415 -0.172751 -0.034992    -0.214614 -0.458915
# MO          -0.148291 -0.036506 -0.160631 -0.034621     0.051688  0.490143
# DY           0.001120 -0.022970 -0.000555 -0.024932     0.026784  0.014002
# HR           0.119319  0.252091  0.137320  0.249333     0.025861  0.017635
# PS          -0.155002  0.029455 -0.179142  0.028472    -0.281704 -0.205680
# WS2M         1.000000  0.190518  0.990722  0.196076     0.031534 -0.493096
# WD2M         0.190518  1.000000  0.177912  0.971214    -0.049829 -0.093824
# WS10M        0.990722  0.177912  1.000000  0.183787     0.040918 -0.475352
# WD10M        0.196076  0.971214  0.183787  1.000000    -0.047093 -0.094909
# PRECTOTCORR  0.031534 -0.049829  0.040918 -0.047093     1.000000  0.233966
# RH2M        -0.493096 -0.093824 -0.475352 -0.094909     0.233966  1.000000
# QV2M         0.003066 -0.058097  0.006776 -0.055790     0.330398  0.705679
# T2M          0.573455  0.048235  0.559621  0.052998     0.174033 -0.139715
#
#                  QV2M       T2M
# PM2.5       -0.634232 -0.384147
# MO           0.421070  0.098548
# DY           0.012006  0.005619
# HR           0.089526  0.126755
# PS          -0.605946 -0.590246
# WS2M         0.003066  0.573455
# WD2M        -0.058097  0.048235
# WS10M        0.006776  0.559621
# WD10M       -0.055790  0.052998
# PRECTOTCORR  0.330398  0.174033
# RH2M         0.705679 -0.139715
# QV2M         1.000000  0.567356
# T2M          0.567356  1.000000

# %%
print('Pearson Correlation')
sns.heatmap(df_corr_pearson, annot=True)
sns.set(rc={'figure.figsize': [25, 10]})
plt.show
# Out:
# Pearson Correlation
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Spearman Correlation')
sns.heatmap(df_corr_spearman, annot=True)
sns.set(rc={'figure.figsize': [25, 10]})
plt.show
# Out:
# Spearman Correlation
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Split the Dataset
X = df[['MO',	'DY',	'HR',	'PS',	'WS2M',	'WD2M',	'WS10M', 'WD10M', 'PRECTOTCORR',	'RH2M',	'QV2M',	'T2M']]
y = df['PM2.5']

# %%
X.head()
# Out:
#    MO  DY  HR     PS  WS2M   WD2M  WS10M  WD10M  PRECTOTCORR   RH2M  QV2M  \
# 0   1   1   0  88.03  0.47  317.6   0.77  319.2          0.0  83.08  6.70
# 1   1   1   1  88.00  0.40  310.0   0.64  313.7          0.0  80.28  6.48
# 2   1   1   2  87.96  0.26  319.6   0.46  323.9          0.0  78.29  6.27
# 3   1   1   3  87.93  0.28  300.3   0.46  306.1          0.0  77.32  6.02
# 4   1   1   4  87.91  0.29  329.0   0.51  330.4          0.0  75.66  5.80
#
#     T2M
# 0  8.85
# 1  8.86
# 2  8.74
# 3  8.32
# 4  8.09

# %%
y.head()
# Out:
# 0    75.780952
# 1    56.584127
# 2    49.538710
# 3    47.398438
# 4    42.821875
# Name: PM2.5, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train
# Out:
#        MO  DY  HR     PS  WS2M   WD2M  WS10M  WD10M  PRECTOTCORR   RH2M  \
# 21217   6   3   1  87.04  0.82   35.6   1.63   35.5         0.04  69.49
# 18826   2  24  10  87.90  2.48  201.5   3.15  201.4         0.00  18.51
# 11726   5   4  14  87.36  2.49  226.6   3.15  226.5         8.99  56.59
# 22777   8   7   1  87.00  0.51   57.9   0.91   53.5        27.18  92.67
# 11288   4  16   8  87.40  1.46  226.9   1.85  227.4         0.00  27.03
# ...    ..  ..  ..    ...   ...    ...    ...    ...          ...    ...
# 21575   6  17  23  86.81  0.68   25.1   1.39   25.1         0.27  68.50
# 5390    8  13  14  86.65  3.20  206.7   4.39  206.7         0.85  77.75
# 860     2   5  20  87.37  0.76  262.4   1.57  257.5         0.07  94.17
# 15795  10  21   3  87.78  0.74   11.8   1.17   11.9         0.00  71.16
# 23654   9  12  14  86.97  2.38  173.0   3.24  172.4         2.25  79.52
#
#         QV2M    T2M
# 21217  12.42  20.96
# 18826   2.57  17.17
# 11726  11.24  22.76
# 22777  16.53  20.88
# 11288   6.84  26.87
# ...      ...    ...
# 21575  15.25  24.51
# 5390   19.45  26.40
# 860     6.05   5.43
# 15795   8.36  14.48
# 23654  18.82  25.53
#
# [21043 rows x 12 columns]

# %%
import time

# %%
start_time_rf = time.time()

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)
end_time_rf = time.time()

rf_time = end_time_rf - start_time_rf
print(' --- Execution Time ---')
rf_time
# Out:
#  --- Execution Time ---
# 32.29948306083679

# %%
# Evaluate the Model
# Yearly mean value fill
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Model Performance:")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Model Performance:
# Mean Absolute Error (MAE): 8.44
# Mean Squared Error (MSE): 165.18
# Root Mean Squared Error (RMSE): 12.85
# R² Score: 0.85

# %%
# make prediction on input data
input_data = {
    'MO' : 7,
    'DY' : 9,
    'HR' : 23,
    'PS' : 78.04,
    'WS2M' : 0.82,
    'WD2M' : 35.6,
    'WS10M' : 1.63,
    'WD10M' : 50.5,
    'PRECTOTCORR' : 5.25,
    'RH2M' : 70.49,
    'QV2M' : 16.42,
    'T2M' : 6.96,
    }
# Convert to DataFrame
input_df = pd.DataFrame([input_data])

input_y_pred = model.predict(input_df)
print("\nPredicted value:", input_y_pred)
# Out:
# Predicted value: [13.15301651]

# %%
a = y_test[:24]
pm_value = a.to_frame().reset_index() # converting series into frame
pm_value = pm_value['PM2.5']
pm_value
# Out:
# 0      22.090625
# 1     156.288333
# 2      65.627419
# 3      31.209524
# 4      22.984615
# 5      99.984999
# 6      78.006897
# 7      61.591667
# 8      19.910000
# 9       5.500000
# 10     23.955738
# 11     75.500000
# 12     14.800000
# 13     17.433854
# 14     45.979688
# 15      5.400000
# 16    125.683332
# 17    125.800000
# 18     16.363333
# 19     11.908333
# 20    102.400000
# 21     20.510345
# 22    118.335000
# 23     73.000000
# Name: PM2.5, dtype: float64

# %%
val=[]
b = y_pred[:24]
for i in b:
    val.append(i)

val
# Converting into dataframe
pm_value1= pd.DataFrame(val)
pm_value1
# Out:
#              0
# 0    10.315817
# 1   104.130491
# 2    53.007063
# 3    33.215045
# 4    20.513631
# 5   102.535663
# 6    76.753176
# 7    53.619460
# 8    15.860304
# 9    12.469781
# 10   19.007522
# 11   64.848979
# 12   24.158268
# 13   13.289467
# 14   39.999908
# 15   11.494118
# 16   82.749114
# 17   78.056505
# 18   16.704763
# 19   28.983414
# 20   82.630834
# 21   27.586164
# 22  101.520096
# 23   64.599592

# %%
plt.plot(pm_value)
plt.plot(pm_value1)

plt.show()
